# %% [markdown]
# import libiraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# read csv file and show the head data

# %%
df = pd.read_csv('/content/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# checking the missing data(nulls , Na , duplicates)

# %%
#no duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# checking the unique values

# %%
# unique value
df['Survived'].nunique()
# Out:
# 2

# %%
df['Survived'].unique()
# Out:
# array([0, 1])

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
#a8yr data type -- 8irt el servived
#df['Survived'] = df['Survived'].astype('int8')
#df.info()

# %% [markdown]
# replace values

# %%
df['Survived'].replace({1:'Survived' , 0:' Not Survived'}, inplace=True)
df.head()
# Out:
# <ipython-input-121-b1eb1510f377>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Survived'].replace({1:'Survived' , 0:' Not Survived'}, inplace=True)
#    PassengerId       Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1   Not Survived       3    male  22.0      1      0   7.2500
# 1            2       Survived       1  female  38.0      1      0  71.2833
# 2            3       Survived       3  female  26.0      0      0   7.9250
# ...

# %%
sns.countplot(x='Survived' , hue='Sex' , data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# filling missing data

# %%
#fill el missing data homa kano 2 bas fa 7atet maknhom s
df['Embarked'].fillna('S' , inplace= True)
# Out:
# <ipython-input-65-d7effe15e664>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna('S' , inplace= True)

# %%
sns.countplot(x='Pclass' , hue='Sex' , data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Survived' , hue='Pclass' , data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# fill missing data with mode

# %%
mode_age = df['Age'].mode()

df['Age'].fillna(mode_age[0] , inplace=True)
# Out:
# <ipython-input-73-e93a6c1f66e8>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(mode_age[0] , inplace=True)

# %%
#keda shelna kol el null w 3mlna fill in bel mode
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df['Cabin'].nunique()
# Out:
# 147

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
#need random 10 numbers
df['Name'].sample(n=20)
# Out:
# 884                               Sutehall, Mr. Henry Jr
# 432    Louch, Mrs. Charles Alexander (Alice Adelaide ...
# 261                    Asplund, Master. Edvin Rojj Felix
# 44                         Devaney, Miss. Margaret Delia
# 463                         Milling, Mr. Jacob Christian
# 279                     Abbott, Mrs. Stanton (Rosa Hunt)
# 244                                 Attalah, Mr. Sleiman
# 285                                  Stankovic, Mr. Ivan
# 791                                  Gaskell, Mr. Alfred
# 168                                  Baumann, Mr. John D
# 392                         Gustafsson, Mr. Johan Birger
# 426          Clarke, Mrs. Charles V (Ada Maria Winfield)
# 746                          Abbott, Mr. Rossmore Edward
# 587                     Frolicher-Stehli, Mr. Maxmillian
# 483                               Turkula, Mrs. (Hedwig)
# 94                                     Coxon, Mr. Daniel
# ...

# %% [markdown]
# hashof ely title mrs , mis , mr . mrs 3a4an ashof min 3a4 aktr

# %%
#el mr w mis w keda b3dhim fe . Mr. fa bs2al law kolo fe . de yab2a true or false
df['Name'].apply(lambda x: '.' in x ).all()
# Out:
# np.True_

# %%
#a3mil split
series = df['Name'].apply(lambda x: x.split(', ')[-1].split('. ')[0])

series.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
#column gadid
df['title']=series

# %%
#drop lel name
df.drop('Name', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked title
# 0         A/5 21171   7.2500   NaN        S    Mr
# 1          PC 17599  71.2833   C85        C   Mrs
# 2  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3            113803  53.1000  C123        S   Mrs
# 4            373450   8.0500   NaN        S    Mr

# %%
df['title'].nunique()
# Out:
# 17

# %%
df['title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
# widen categories (small categories may have the same meaning)
df['title'] = df['title'].replace({
                  'Col': 'Colonel',
                  'Mme': 'Mrs',
                  'Capt': 'Captain',
                  'Mlle': 'Miss',
                  'Dona': 'Mrs',
                  'Don': 'Mr',
                  'Rev': 'Reverend'
              })

df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked title
# 0         A/5 21171   7.2500   NaN        S    Mr
# 1          PC 17599  71.2833   C85        C   Mrs
# 2  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3            113803  53.1000  C123        S   Mrs
# 4            373450   8.0500   NaN        S    Mr

# %%
df['title'].value_counts()
# Out:
# title
# Mr              518
# Miss            184
# Mrs             126
# Master           40
# Dr                7
# Reverend          6
# Major             2
# Colonel           2
# Lady              1
# Ms                1
# Sir               1
# Captain           1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %%
#sum klmt Ms ely 3ndi
f = df['title'] == 'Ms'
f.sum()
# Out:
# np.int64(1)

# %%
#call
df[f]
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  Ticket  Fare  \
# 443          444         1       2  female  28.0      0      0  230434  13.0
#
#     Cabin Embarked title
# 443   NaN        S    Ms

# %%
df.replace({'Ms': 'Miss'}, inplace = True)
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked     title
# 0           A/5 21171   7.2500   NaN        S        Mr
# 1            PC 17599  71.2833   C85        C       Mrs
# ...

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df['Ticket'].nunique()
# Out:
# 681

# %%
#drop column
df.drop('Ticket', axis=1, inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked title
# 0        S    Mr
# 1        C   Mrs
# 2        S  Miss
# 3        S   Mrs
# 4        S    Mr

# %%
df.drop('Cabin', axis=1, inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked title
# 0        S    Mr
# 1        C   Mrs
# 2        S  Miss
# 3        S   Mrs
# 4        S    Mr

# %%
sns.countplot(x='Survived',hue='title',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# Create a mapping for the unique values in 'Embarked'
mapping = {'S': 'Southampton', 'C': 'Cherbourg', 'Q': 'Queenstown'}

# Apply the mapping to the 'Embarked' column
df['Embarked'] = df['Embarked'].map(mapping)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#       Embarked title
# 0  Southampton    Mr
# 1    Cherbourg   Mrs
# 2  Southampton  Miss
# 3  Southampton   Mrs
# 4  Southampton    Mr

# %%
sns.countplot(x='Embarked' , hue='Survived' , data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(x='Embarked' , data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
#outlier
median = df['Fare'].median()
median
# Out:
# 14.4542

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
#el file asmo project 1 ashal el tare2a
q1 = df['Fare'].quantile(0.25)
q3 = df['Fare'].quantile(0.75)

iqr = q3 - q1

lower_whisker = q1 - 1.5 * iqr
if lower_whisker < 0:
    lower_whisker = 0

upper_whisker = q3 + 1.5 * iqr

q1, q3, iqr, lower_whisker, upper_whisker
# Out:
# (np.float64(7.9104),
#  np.float64(31.0),
#  np.float64(23.0896),
#  0,
#  np.float64(65.6344))

# %%
# having fares above upper whisker can be considered as mathematical outliers but we should keep it, because it can mean that the person is rich which can reflect his survival probability
filt_lower = df['Fare'] < lower_whisker
filt_upper = df['Fare'] > upper_whisker
filt = filt_lower | filt_upper
outlier_indices = df[filt].index
# df.drop(outlier_indices, inplace = True) --- prefer not to drop

# %%
outlier_indices
# Out:
# Index([  1,  27,  31,  34,  52,  61,  62,  72,  88, 102,
#        ...
#        792, 802, 820, 829, 835, 846, 849, 856, 863, 879],
#       dtype='int64', length=116)

# %%
df.to_csv('titanic2.csv' )

# %%
#atsyft fe content
df.to_csv('titanic22.csv', index=False)
